# %%
import pandas as pd
modifiedCases_2020=pd.read_csv("COVID19 cases Toronto.csv")

# %%
df=pd.read_csv("COVID19 cases Toronto.csv")
df
# Out:
#          _id  Outbreak Associated       Age Group Neighbourhood Name  FSA  \
# 0      44294             Sporadic           50-59            Malvern  M1B
# 1      44295             Sporadic           20-29            Malvern  M1B
# 2      44296             Sporadic           60-69            Malvern  M1B
# 3      44297  Outbreak Associated           50-59              Rouge  M1B
# 4      44298             Sporadic           30-39              Rouge  M1B
# ...      ...                  ...             ...                ...  ...
# 14906  59200  Outbreak Associated           50-59                NaN  NaN
# 14907  59201  Outbreak Associated           20-29                NaN  NaN
# 14908  59202  Outbreak Associated           40-49                NaN  NaN
# 14909  59203  Outbreak Associated  19 and younger                NaN  NaN
# 14910  59204  Outbreak Associated           50-59                NaN  NaN
#
#              Source of Infection Classification Episode Date Reported Date  \
# ...

# %%
df.columns = ['Id','OutbreakAssociated','AgeGroup','NeighbourhoodName','FSA','SourceofInfection','Classification','EpisodeDate','ReportedDate','ClientGender','Outcome','CurrentlyHospitalized','CurrentlyinICU','CurrentlyIntubated','EverHospitalized','EverinICU','EverIntubated']
df
# Out:
#           Id   OutbreakAssociated        AgeGroup NeighbourhoodName  FSA  \
# 0      44294             Sporadic           50-59           Malvern  M1B
# 1      44295             Sporadic           20-29           Malvern  M1B
# 2      44296             Sporadic           60-69           Malvern  M1B
# 3      44297  Outbreak Associated           50-59             Rouge  M1B
# 4      44298             Sporadic           30-39             Rouge  M1B
# ...      ...                  ...             ...               ...  ...
# 14906  59200  Outbreak Associated           50-59               NaN  NaN
# 14907  59201  Outbreak Associated           20-29               NaN  NaN
# 14908  59202  Outbreak Associated           40-49               NaN  NaN
# 14909  59203  Outbreak Associated  19 and younger               NaN  NaN
# 14910  59204  Outbreak Associated           50-59               NaN  NaN
#
#                SourceofInfection Classification EpisodeDate ReportedDate  \
# ...

# %%
df['EpisodeDate'] = pd.to_datetime(df.EpisodeDate)
df.head(10)
# Out:
#       Id   OutbreakAssociated        AgeGroup NeighbourhoodName  FSA  \
# 0  44294             Sporadic           50-59           Malvern  M1B
# 1  44295             Sporadic           20-29           Malvern  M1B
# 2  44296             Sporadic           60-69           Malvern  M1B
# 3  44297  Outbreak Associated           50-59             Rouge  M1B
# 4  44298             Sporadic           30-39             Rouge  M1B
# 5  44299             Sporadic           20-29             Rouge  M1B
# 6  44300             Sporadic           60-69             Rouge  M1B
# 7  44301             Sporadic           30-39             Rouge  M1B
# 8  44302             Sporadic           30-39           Malvern  M1B
# 9  44303             Sporadic  19 and younger           Malvern  M1B
#
#            SourceofInfection Classification EpisodeDate ReportedDate  \
# 0              Institutional      CONFIRMED  2020-03-25   27-03-2020
# ...

# %%
df['ReportedDate'] = pd.to_datetime(df.ReportedDate)
df.head(20)
# Out:
#        Id   OutbreakAssociated        AgeGroup NeighbourhoodName  FSA  \
# 0   44294             Sporadic           50-59           Malvern  M1B
# 1   44295             Sporadic           20-29           Malvern  M1B
# 2   44296             Sporadic           60-69           Malvern  M1B
# 3   44297  Outbreak Associated           50-59             Rouge  M1B
# 4   44298             Sporadic           30-39             Rouge  M1B
# 5   44299             Sporadic           20-29             Rouge  M1B
# 6   44300             Sporadic           60-69             Rouge  M1B
# 7   44301             Sporadic           30-39             Rouge  M1B
# 8   44302             Sporadic           30-39           Malvern  M1B
# 9   44303             Sporadic  19 and younger           Malvern  M1B
# 10  44304             Sporadic           30-39           Malvern  M1B
# 11  44305  Outbreak Associated           20-29           Malvern  M1B
# ...
